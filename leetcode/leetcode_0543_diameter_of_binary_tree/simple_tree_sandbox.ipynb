# %%
from common.simple_tree import TreeNode, breadth_first_build, draw_tree

# %%
t = breadth_first_build([1,2,3,4,5])
draw_tree(t)

# %%
def tree_dia(t: TreeNode):
    if t is None or (t.left is None and t.right is None):
        return 0
    raise NotImplementedError()

# %%
tree_dia(t.right.right)
# Out:
# 0

# %%
tree_dia(t.right)
# Out:
# 0
